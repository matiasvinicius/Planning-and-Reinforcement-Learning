# %%
import gym
import keras_gym as km
from tensorflow.keras.layers import Conv2D, Lambda, Dense, Flatten
from tensorflow.keras import backend as K
# Out:
# /home/vinicius/.local/lib/python3.8/site-packages/keras_gym/base/patches.py:23: UserWarning: keras-gym has known issues with eager execution mode; eager execution has been disabled as a precaution. You may try and enable eager execution with: tf.compat.v1.enable_eager_execution()
#   warnings.warn(

# %%
env = gym.make('Freeway-v0')
env = km.wrappers.ImagePreprocessor(env, height=84, width=84, grayscale=True)
env = km.wrappers.FrameStacker(env, num_frames=3)
env = km.wrappers.TrainMonitor(env)

# %%
km.enable_logging()

# %%
class Func(km.FunctionApproximator):
    def body(self, S):
        def diff_transform(S):
            S = K.cast(S, 'float32') / 255
            M = km.utils.diff_transform_matrix(num_frames=3)
            return K.dot(S, M)

        X = Lambda(diff_transform)(S)
        X = Conv2D(filters=32, kernel_size=8, strides=4, activation='relu')(X)
        X = Conv2D(filters=64, kernel_size=4, strides=2, activation='relu')(X)
        X = Conv2D(filters=64, kernel_size=3, strides=2, activation='relu')(X)
        X = Flatten()(X)
        X = Dense(units=512, activation='relu')(X)
        X = Dense(units=256, activation='relu')(X)        
        X = Dense(units=3, activation='linear')(X)
        return X

# %%
func = Func(env, lr=0.01)
pi = km.SoftmaxPolicy(func, update_strategy='ppo')
v = km.V(func, gamma=0.99, bootstrap_n=250000, bootstrap_with_target_model=True)
actor_critic = km.ActorCritic(pi, v)

# %%
buffer = km.caching.ExperienceReplayBuffer.from_value_function(
    value_function=v, capacity=100000, batch_size=64)

# %%
while env.T < 1000000:
    s = env.reset()

    for t in range(env.spec.max_episode_steps):
        a = pi(s, use_target_model=True)  # target_model == pi_old
        s_next, r, done, info = env.step(a)

        buffer.add(s, a, r, done, env.ep)

        if len(buffer) >= buffer.capacity:
            num_batches = int(4 * buffer.capacity / buffer.batch_size)
            for _ in range(num_batches):
                actor_critic.batch_update(*buffer.sample())
            buffer.clear()

            actor_critic.sync_target_model(tau=0.5)

        if done:
            break

        s = s_next

    if env.ep % 50 == 0:
        km.utils.generate_gif(
            env=env,
            policy=pi,
            filepath='Logs/{:06d}.gif'.format(env.ep),
            resize_to=(320, 420))
# Out:
# ms
# INFO:TrainMonitor:ep: 60, T: 163,907, G: 0, avg_G: 0, t: 2725, dt: 4.903ms
# INFO:TrainMonitor:ep: 61, T: 166,652, G: 0, avg_G: 0, t: 2744, dt: 4.910ms
# INFO:TrainMonitor:ep: 62, T: 169,376, G: 0, avg_G: 0, t: 2723, dt: 4.923ms
# INFO:TrainMonitor:ep: 63, T: 172,104, G: 0, avg_G: 0, t: 2727, dt: 4.904ms
# INFO:TrainMonitor:ep: 64, T: 174,843, G: 0, avg_G: 0, t: 2738, dt: 4.917ms
# INFO:TrainMonitor:ep: 65, T: 177,573, G: 0, avg_G: 0, t: 2729, dt: 4.976ms
# INFO:TrainMonitor:ep: 66, T: 180,312, G: 0, avg_G: 0, t: 2738, dt: 4.907ms
# INFO:TrainMonitor:ep: 67, T: 183,057, G: 0, avg_G: 0, t: 2744, dt: 4.904ms
# INFO:TrainMonitor:ep: 68, T: 185,810, G: 0, avg_G: 0, t: 2752, dt: 4.968ms
ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 177, T: 483,674, G: 0, avg_G: 0, t: 2742, dt: 5.457ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 178, T: 486,394, G: 0, avg_G: 0, t: 2719, dt: 5.263ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 179, T: 489,122, G: 0, avg_G: 0, t: 2727, dt: 5.698ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 180, T: 491,848, G: 0, avg_G: 0, t: 2725, dt: 5.588ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 181, T: 494,591, G: 0, avg_G: 0, t: 2742, dt: 5.204ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 182, T: 497,346, G: 0, avg_G: 0, t: 2754, dt: 5.439ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 183, T: 500,079, G: 0, avg_G: 0, t: 2732, dt: 5.724ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 184, T: 502,812, G: 0, avg_G: 0, t: 2732, dt: 5.450ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 185, T: 505,560, G: 0, avg_G: 0, t: 2747, dt: 5.943ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 186, T: 508,298, G: 0, avg_G: 0, t: 2737, dt: 5.559ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 187, T: 511,039, G: 0, avg_G: 0, t: 2740, dt: 5.388ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 188, T: 513,771, G: 0, avg_G: 0, t: 2731, dt: 5.022ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 189, T: 516,526, G: 0, avg_G: 0, t: 2754, dt: 5.059ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 190, T: 519,271, G: 0, avg_G: 0, t: 2744, dt: 5.058ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 191, T: 521,971, G: 0, avg_G: 0, t: 2699, dt: 5.320ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 192, T: 524,727, G: 0, avg_G: 0, t: 2755, dt: 5.028ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 193, T: 527,459, G: 0, avg_G: 0, t: 2731, dt: 5.186ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 194, T: 530,188, G: 0, avg_G: 0, t: 2728, dt: 5.167ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 195, T: 532,921, G: 0, avg_G: 0, t: 2732, dt: 5.239ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 196, T: 535,644, G: 0, avg_G: 0, t: 2722, dt: 5.184ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 197, T: 538,365, G: 0, avg_G: 0, t: 2720, dt: 5.094ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 198, T: 541,098, G: 0, avg_G: 0, t: 2732, dt: 5.236ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 199, T: 543,823, G: 0, avg_G: 0, t: 2724, dt: 5.243ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 200, T: 546,562, G: 0, avg_G: 0, t: 2738, dt: 5.015ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:TrainMonitor:ep: 201, T: 549,326, G: 0, avg_G: 0, t: 2763, dt: 8.365ms, loss: -0.011, policy/entropy: 1.1, policy/kl_div: 0, policy/loss: -0.011, value/loss: 0
# INFO:generate_gif:recorded episode to: Logs/000200.gif
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-88af02711380> in <module>
#      11             num_batches = int(4 * buffer.capacity / buffer.batch_size)
#      12             for _ in range(num_batches):
# ---> 13                 actor_critic.batch_update(*buffer.sample())
#      14             buffer.clear()
#      15
#
# ~/.local/lib/python3.8/site-packages/keras_gym/core/actor_critic.py in batch_update(self, S, A, Rn, In, S_next, A_next)
#     213             raise ActionSpaceError.feature_request(self.env)
#     214
# --> 215         losses = self._train_on_batch([S, A, G])
#     216         return losses
#     217
#
# ~/.local/lib/python3.8/site-packages/keras_gym/core/base.py in _train_on_batch(self, inputs, outputs)
#      56
#      57         """
# ---> 58         losses = self.train_model.train_on_batch(inputs, outputs)
#      59
#      60         # add metric names
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_v1.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1087       self._update_sample_weight_modes(sample_weights=sample_weights)
#    1088       self._make_train_function()
# -> 1089       outputs = self.train_function(ins)  # pylint: disable=not-callable
#    1090
#    1091     if reset_metrics:
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3822       self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
#    3823
# -> 3824     fetched = self._callable_fn(*array_vals,
#    3825                                 run_metadata=self.run_metadata)
#    3826     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1468       try:
#    1469         run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
#    1472                                                run_metadata_ptr)
#
# KeyboardInterrupt:
