# %%
import matplotlib.pyplot as plt
import gym
import csv
import random
import logging
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Convolution2D
from tensorflow.keras.optimizers import Adam
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy
import wandb
from rl.agents import DQNAgent
from rl.memory import SequentialMemory
from keras.callbacks import CSVLogger

# %%
def build_model(height, width, channels, actions):
    model = Sequential()
    model.add(Convolution2D(32, (8, 8), strides=(4, 4),
              activation='relu', input_shape=(3, height, width, channels)))
    model.add(Convolution2D(64, (4, 4), strides=(2, 2), activation='relu'))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
def build_agent(model, actions):
    policy = LinearAnnealedPolicy(EpsGreedyQPolicy(
    ), attr='eps', value_max=1, value_min=.1, value_test=.2, nb_steps=1000000)
    memory = SequentialMemory(limit=1000, window_length=3)
    dqn = DQNAgent(model=model, memory=memory, policy=policy,
                   enable_dueling_network=True, dueling_type='avg',
                   nb_actions=actions, nb_steps_warmup = 1000000)
    return dqn

# %%
env = gym.make("Freeway-v0")
env = gym.wrappers.ResizeObservation(env, (88, 88))
height, width, channels = env.observation_space.shape
actions = env.action_space.n
model = build_model(height, width, channels, actions)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 3, 21, 21, 32)     6176
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 3, 9, 9, 64)       32832
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 7, 7, 64)       36928
# _________________________________________________________________
# flatten (Flatten)            (None, 9408)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4817408
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 5,025,443
# Trainable params: 5,025,443
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
dqn = build_agent(model, actions)
dqn.compile(Adam(learning_rate=0.0001))
log = dqn.fit(env, nb_steps=1000000, visualize=True, verbose=2)
# Out:
# Training for 100000 steps ...
# /home/vinicius/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
#   2707/100000: episode: 1, duration: 21.196s, episode steps: 2707, steps per second: 128, episode reward:  1.000, mean reward:  0.000 [ 0.000,  1.000], mean action: 0.996 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#   5437/100000: episode: 2, duration: 20.264s, episode steps: 2730, steps per second: 135, episode reward:  0.000, mean reward:  0.000 [ 0.000,  0.000], mean action: 1.001 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#   8152/100000: episode: 3, duration: 21.636s, episode steps: 2715, steps per second: 125, episode reward:  1.000, mean reward:  0.000 [ 0.000,  1.000], mean action: 1.000 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  10906/100000: episode: 4, duration: 20.471s, episode steps: 2754, steps per second: 135, episode reward:  0.000, mean reward:  0.000 [ 0.000,  0.000], mean action: 1.016 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  13653/100000: episode: 5, duration: 19.836s, episode steps: 2747, steps per second: 138, episode reward:  0.000, mean reward:  0.000 [ 0.000,  0.000], mean action: 1.006 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  16384/100000: episode: 6, duration: 20.987s, episode steps: 2731, steps per second: 130, episode reward:  0.000, mean reward:  0.000 [ 0.000,  0.000], mean action: 1.003 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  19114/100000: episode: 7, duration: 19.919s, episode steps: 2730, steps per second: 137, episode reward:  1.000, mean reward:  0.000 [ 0.000,  1.000], mean action: 0.977 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  21864/100000: episode: 8, duration: 19.806s, episode steps: 2750, steps per second: 139, episode reward:  1.000, mean reward:  0.000 [ 0.000,  1.000], mean action: 0.986 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  24570/100000: episode: 9, duration: 21.454s, episode steps: 2706, steps per second: 126, episode reward:  2.000, mean reward:  0.001 [ 0.000,  1.000], mean action: 0.998 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  27302/100000: episode: 10, duration: 20.997s, episode steps: 2732, steps per second: 130, episode reward:  1.000, mean reward:  0.000 [ 0.000,  1.000], mean action: 1.025 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  30040/100000: episode: 11, duration: 20.083s, episode steps: 2738, steps per second: 136, episode reward:  3.000, mean reward:  0.001 [ 0.000,  1.000], mean action: 1.010 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  32760/100000: episode: 12, duration: 20.020s, episode steps: 2720, steps per second: 136, episode reward:  6.000, mean reward:  0.002 [ 0.000,  1.000], mean action: 0.998 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  35490/100000: episode: 13, duration: 21.675s, episode steps: 2730, steps per second: 126, episode reward:  6.000, mean reward:  0.002 [ 0.000,  1.000], mean action: 1.000 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  38209/100000: episode: 14, duration: 21.591s, episode steps: 2719, steps per second: 126, episode reward:  5.000, mean reward:  0.002 [ 0.000,  1.000], mean action: 1.000 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  40929/100000: episode: 15, duration: 21.605s, episode steps: 2720, steps per second: 126, episode reward:  7.000, mean reward:  0.003 [ 0.000,  1.000], mean action: 1.018 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  43684/100000: episode: 16, duration: 21.441s, episode steps: 2755, steps per second: 128, episode reward:  8.000, mean reward:  0.003 [ 0.000,  1.000], mean action: 0.984 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  46431/100000: episode: 17, duration: 19.970s, episode steps: 2747, steps per second: 138, episode reward:  8.000, mean reward:  0.003 [ 0.000,  1.000], mean action: 0.994 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  49157/100000: episode: 18, duration: 19.470s, episode steps: 2726, steps per second: 140, episode reward:  9.000, mean reward:  0.003 [ 0.000,  1.000], mean action: 1.020 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  51898/100000: episode: 19, duration: 21.429s, episode steps: 2741, steps per second: 128, episode reward: 12.000, mean reward:  0.004 [ 0.000,  1.000], mean action: 0.992 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  54621/100000: episode: 20, duration: 20.738s, episode steps: 2723, steps per second: 131, episode reward: 11.000, mean reward:  0.004 [ 0.000,  1.000], mean action: 1.006 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  57360/100000: episode: 21, duration: 19.640s, episode steps: 2739, steps per second: 139, episode reward: 13.000, mean reward:  0.005 [ 0.000,  1.000], mean action: 1.004 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  60099/100000: episode: 22, duration: 19.659s, episode steps: 2739, steps per second: 139, episode reward: 12.000, mean reward:  0.004 [ 0.000,  1.000], mean action: 0.992 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  62822/100000: episode: 23, duration: 19.855s, episode steps: 2723, steps per second: 137, episode reward: 14.000, mean reward:  0.005 [ 0.000,  1.000], mean action: 1.018 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  65555/100000: episode: 24, duration: 20.087s, episode steps: 2733, steps per second: 136, episode reward: 13.000, mean reward:  0.005 [ 0.000,  1.000], mean action: 0.996 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  68292/100000: episode: 25, duration: 21.508s, episode steps: 2737, steps per second: 127, episode reward: 14.000, mean reward:  0.005 [ 0.000,  1.000], mean action: 0.991 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  70987/100000: episode: 26, duration: 20.498s, episode steps: 2695, steps per second: 131, episode reward: 17.000, mean reward:  0.006 [ 0.000,  1.000], mean action: 0.999 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  73712/100000: episode: 27, duration: 19.870s, episode steps: 2725, steps per second: 137, episode reward: 16.000, mean reward:  0.006 [ 0.000,  1.000], mean action: 0.997 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  76446/100000: episode: 28, duration: 20.415s, episode steps: 2734, steps per second: 134, episode reward: 14.000, mean reward:  0.005 [ 0.000,  1.000], mean action: 1.010 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  79154/100000: episode: 29, duration: 19.270s, episode steps: 2708, steps per second: 141, episode reward: 20.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 0.989 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  81885/100000: episode: 30, duration: 20.614s, episode steps: 2731, steps per second: 132, episode reward: 20.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 1.022 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  84629/100000: episode: 31, duration: 19.895s, episode steps: 2744, steps per second: 138, episode reward: 16.000, mean reward:  0.006 [ 0.000,  1.000], mean action: 1.008 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  87350/100000: episode: 32, duration: 18.600s, episode steps: 2721, steps per second: 146, episode reward: 18.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 1.005 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  90082/100000: episode: 33, duration: 18.666s, episode steps: 2732, steps per second: 146, episode reward: 20.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 1.005 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  92812/100000: episode: 34, duration: 21.577s, episode steps: 2730, steps per second: 127, episode reward: 19.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 0.995 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  95553/100000: episode: 35, duration: 19.544s, episode steps: 2741, steps per second: 140, episode reward: 22.000, mean reward:  0.008 [ 0.000,  1.000], mean action: 0.999 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
#  98276/100000: episode: 36, duration: 20.020s, episode steps: 2723, steps per second: 136, episode reward: 18.000, mean reward:  0.007 [ 0.000,  1.000], mean action: 0.992 [0.000, 2.000],  loss: --, mean_q: --, mean_eps: --
# done, took 747.350 seconds

# %%
scores = dqn.test(env, nb_episodes = 10, visualize=True)
print(np.mean(scores.history['episode_reward']))
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 21.000, steps: 2746
# Episode 2: reward: 21.000, steps: 2716
# Episode 3: reward: 21.000, steps: 2741
# Episode 4: reward: 23.000, steps: 2710
# Episode 5: reward: 21.000, steps: 2737
# Episode 6: reward: 21.000, steps: 2718
# Episode 7: reward: 21.000, steps: 2741
# Episode 8: reward: 21.000, steps: 2716
# Episode 9: reward: 21.000, steps: 2705
# Episode 10: reward: 21.000, steps: 2735
# 21.2

# %%
env.close()

# %%
plt.plot(log.epoch, log.history['episode_reward'])
plt.title("Treinamento")
plt.xlabel("Épocas")
plt.ylabel("Score")
plt.savefig('1M_dqn_train.png')
# Out:
# Text(0, 0.5, 'Score')

# %%
plt.plot(scores.epoch, scores.history['episode_reward'])
plt.title("Teste")
plt.xlabel("Épocas")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')
